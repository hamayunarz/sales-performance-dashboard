# %%
from sqlalchemy import text
import sys
import os

# %%
sys.path.append(os.path.abspath(".."))
from db_connect import get_engine

# %%
# Connect to database
engine = get_engine()

# %%
# Read the SQL file
with open("../sql/queries/fix_column_types.sql", "r") as file:
    query = file.read()

# %%
# Execute SQL
with engine.begin() as conn:
    conn.execute(text(query))
