# %%
import pandas as pd
from db_connect import get_engine

# %%
# Load SQL query from file
with open("../sql/queries/01_sales_summary.sql", "r") as file:
    query = file.read()

# %%
# Create engine and fetch query results
engine = get_engine()
df = pd.read_sql(query, con=engine)
df
# Out:
#    total_orders  unique_customers  total_sales            total_profit  \
# 0         51290              4873   12642905.0  (1467457.2912799867,2)
#
#    avg_order_value   profit_margin_percent
# 0            246.5  (11.606962887722297,2)
